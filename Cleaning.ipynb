# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/Content.csv')
df1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
df2 = pd.read_csv('/content/ReactionTypes.csv')
df2.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
df3 = pd.read_csv('/content/Reactions.csv')
df3.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
print(df1.isnull().mean())
# Out:
# User ID    0.0
# Type       0.0
# dtype: float64

# %%
df1 = df1.drop(columns=['Unnamed: 0'])

# %%
df1.head()
# Out:
#                                 User ID   Type
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video

# %%
df2 = df2.drop(columns=['Unnamed: 0'])
df2.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %%
print(df2.isnull().mean())
# Out:
# Type         0.0
# Sentiment    0.0
# Score        0.0
# dtype: float64

# %%
print(df3.isnull().mean())
# Out:
# Unnamed: 0    0.000000
# Content ID    0.000000
# User ID       0.118147
# Type          0.038352
# Datetime      0.000000
# dtype: float64

# %%
df3 = df3.drop(columns=['Unnamed: 0'])
df3.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2                                   NaN
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
#
#       Type             Datetime
# 0      NaN  2021-04-22 15:17:15
# 1  disgust  2020-11-07 09:43:50
# 2  dislike  2021-06-17 12:22:51
# 3   scared  2021-04-18 05:13:58
# 4  disgust  2021-01-06 19:13:01

# %%
df3.dropna(subset=['User ID', 'Type'])
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# ...

# %%
print(df3.isnull().mean())
# Out:
# Content ID    0.000000
# User ID       0.118147
# Type          0.038352
# Datetime      0.000000
# dtype: float64

# %%
# Identify the first valid index
first_valid = df3.apply(pd.Series.first_valid_index)

# %%
# Find the maximum index among the first valid indices
max_index = max(first_valid)

# %%
# Drop the leading rows containing NaN
df4 = df3.loc[max_index:]

# %%
df3[df3.iloc[:,2]=='NaN']
# Out:
# Empty DataFrame
# Columns: [Content ID, User ID, Type, Datetime]
# Index: []

# %%
null_data = df3[df3.isnull().any(axis=1)]
print(null_data)
# Out:
#                                  Content ID User ID        Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN         NaN
# 10     97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN        love
# 20     97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN   intrigued
# 30     97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN   intrigued
# 40     97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN     dislike
# ...                                     ...     ...         ...
# 25519  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN        love
# 25529  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN     dislike
# 25539  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN     cherish
# 25540  75d6b589-7fae-4a6d-b0d0-752845150e56     NaN         NaN
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56     NaN  interested
#
#                   Datetime
# 0      2021-04-22 15:17:15
# 10     2020-08-04 05:05:02
# 20     2021-01-31 16:03:56
# 30     2020-08-25 08:21:56
# 40     2020-11-29 21:33:04
# ...                    ...
# ...

# %%
df4 = df3.dropna(how='any')

# %%
print(df4.isnull().mean())
# Out:
# Content ID    0.0
# User ID       0.0
# Type          0.0
# Datetime      0.0
# dtype: float64

# %%
df1.dtypes
# Out:
# User ID    object
# Type       object
# dtype: object

# %%
df2.dtypes
# Out:
# Type         object
# Sentiment    object
# Score         int64
# dtype: object

# %%
df3.dtypes
# Out:
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# dtype: object

# %%
import pandas as pd
df3['User ID'] = pd.to_numeric(df3['User ID'], errors='coerce')
print(df3.dtypes)
# Out:
# Content ID     object
# User ID       float64
# Type           object
# Datetime       object
# dtype: object

# %%
import pandas as pd
df3['Type'] = pd.to_numeric(df3['Type'], errors='coerce')
print(df3.dtypes)
# Out:
# Content ID     object
# User ID       float64
# Type          float64
# Datetime       object
# dtype: object

# %%
import pandas as pd
df2['Type'] = pd.to_numeric(df2['Type'], errors='coerce')
print(df2.dtypes)
# Out:
# Type         float64
# Sentiment     object
# Score          int64
# dtype: object

# %%
import pandas as pd
df1['Type'] = pd.to_numeric(df1['Type'], errors='coerce')
print(df1.dtypes)
# Out:
# User ID     object
# Type       float64
# dtype: object

# %%
import pandas as pd
df1['User ID'] = pd.to_numeric(df3['User ID'], errors='coerce')
print(df1.dtypes)
# Out:
# User ID    float64
# Type       float64
# dtype: object

# %%
# saving the dataframe
df1.to_csv('file1.csv')

# %%
# saving the dataframe
df2.to_csv('file2.csv')

# %%
# saving the dataframe
df3.to_csv('file3.csv')
